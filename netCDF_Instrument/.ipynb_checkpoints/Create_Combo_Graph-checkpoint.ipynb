# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import mpld3
import NetCDF_Utils.grapher as grapher
import pandas as pd
from DepthCalculation.depth import Depth as depth
from functools import reduce
import IPython.html.widgets as widgets
plt.rcParams['figure.figsize'] = (10, 5)


mpld3.enable_notebook()

# %%
class PlotWave(object):
    
    def __init__(self):
        self.wave = np.linspace(-np.pi, np.pi, 200)
        self.amp = 1
        self.period = 1
        self.cos = False
        self.equation = '(%ssin(x*%s))' %(self.amp,self.period)
        
    def get_wave(self):
        if self.cos == False:
            self.equation = '(%ssin(x*%s))' %(self.amp,self.period)
            return np.multiply(self.amp,np.sin(self.wave*self.period))
        else:
            self.equation = '(%scos(x*%s))' %(self.amp,self.period)
            return np.multiply(self.amp,np.cos(self.wave*self.period))
        
z_offset = [0]
values = []
for x in range(0,6):
    values.append(PlotWave())
pressure_data = [0]

# %%
def change_z(z):
    z_offset[0] = z
    f()
    
def f():
    print(len(values))
    x = np.linspace(-np.pi, np.pi, 200)
    pressure_data[0] = np.add(reduce(np.add,[x.get_wave() for x in values]),z_offset[0])
    plt.plot(x,np.add(reduce(np.add,[x.get_wave() for x in values]),z_offset[0]))
    plt.grid(b=True, which='major', color='grey', linestyle="-",alpha=0.5)
    plt.show()
    
    
def change_value(plot_num, amp, period, cos):
  
    plot = values[plot_num]
    if amp != None:
        plot.amp = amp
    if period != None:
        plot.period = period
    if cos != None:
        plot.cos = cos
        
    f()

# %%
lims = (1,20,2)
alims = (1,5,1)
z_lims = (-5,15,1)
widgets.interact(change_z, z = z_lims)
for x in range(0,len(values)):
    widgets.interact(change_value, plot_num = widgets.fixed(x), amp = alims, period = lims, cos = False)
# Out:
# 6

# %%
from NetCDF_Utils.ExportCombinationGraph import export_netCDF

def export():
   
    z_offset[0] = str(z_offset[0])
    equation = ''.join(['%s + ' % x.equation for x in values] + z_offset)
    exp = export_netCDF(pressure_data[0],equation)
    print(pressure_data[0],equation)
    exp.export()

# %%
export()
# Out:
# Done with initialization
# [  5.          -0.04639413  -4.6880303   -8.55261515 -11.33018052
#  -12.79794522 -12.83818373 -11.44766863  -8.73792945  -4.92630722
#   -0.31852209   4.71584764   9.77300849  14.44733893  18.36392326
#   21.20862258  22.75327109  22.8739766   21.56105763  18.91981996
#   15.16211029  10.58932457   5.5682339    0.50156668  -4.20429308
#   -8.17190079 -11.08302512 -12.70417247 -12.90531489 -11.67031927
#   -9.09824137  -5.39538074  -0.85873408   4.14782618   9.22273705
#   13.95895333  17.97659562  20.95341943  22.6506616   22.9321908
#   21.77542632  19.2731492   15.62606045  11.12668346   6.13590136
#    1.05401162  -3.71138082  -7.7780564  -10.81983782 -12.59275181
#  -12.95459764 -11.87635259  -9.44449986  -5.85409193  -1.39310595
#    3.58065418   8.66825629  13.46163725  17.57633263  20.68231357
#   22.53045755  22.97252981  21.97307291  19.61225064  16.07941834
#   11.65793514   6.70243654   1.61039     -3.20978487  -7.37147457
#  -10.54088096 -12.46379432 -12.98598285 -12.06556318  -9.77635975
#   -6.30198352  -1.92110503   3.01489702   8.11011894  12.95588643
#   17.16353328  20.39557523  22.39277875  22.99495341  22.15380036
#   19.93678628  16.52173201  12.18255004   7.26727469   2.17014723
#   -2.70000522  -6.95256058 -10.24643261 -12.31742854 -12.99943924
#  -12.23776245 -10.09349025  -6.73860905  -2.44220501   2.45111865
#    7.54888135  12.44220501  16.73860905  20.09349025  22.23776245
#   22.99943924  22.31742854  20.24643261  16.95256058  12.70000522
#    7.82985277   2.73272531  -2.18255004  -6.52173201  -9.93678628
#  -12.15380036 -12.99495341 -12.39277875 -10.39557523  -7.16353328
#   -2.95588643   1.88988106   6.98510298  11.92110503  16.30198352
#   19.77635975  22.06556318  22.98598285  22.46379432  20.54088096
#   17.37147457  13.20978487   8.38961      3.29756346  -1.65793514
#   -6.07941834  -9.61225064 -11.97307291 -12.97252981 -12.53045755
#  -10.68231357  -7.57633263  -3.46163725   1.33174371   6.41934582
#   11.39310595  15.85409193  19.44449986  21.87635259  22.95459764
#   22.59275181  20.81983782  17.7780564   13.71138082   8.94598838
#    3.86409864  -1.12668346  -5.62606045  -9.2731492  -11.77542632
#  -12.9321908  -12.6506616  -10.95341943  -7.97659562  -3.95895333
#    0.77726295   5.85217382  10.85873408  15.39538074  19.09824137
#   21.67031927  22.90531489  22.70417247  21.08302512  18.17190079
#   14.20429308   9.49843332   4.4317661   -0.58932457  -5.16211029
#   -8.91981996 -11.56105763 -12.8739766  -12.75327109 -11.20862258
#   -8.36392326  -4.44733893   0.22699151   5.28415236  10.31852209
#   14.92630722  18.73792945  21.44766863  22.83818373  22.79794522
#   21.33018052  18.55261515  14.6880303   10.04639413   5.        ] (3sin(x*9)) + (3sin(x*9)) + (3sin(x*9)) + (3sin(x*9)) + (3sin(x*9)) + (3sin(x*9)) + 5
# done set
# P0DT0H0M49.75S
# done write
